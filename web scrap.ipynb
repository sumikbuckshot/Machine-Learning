# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url='https://en.wikipedia.org/wiki/Saprotrophic_nutrition'

# %%
#we ARE sending reques to the url and taking the response 
response=requests.get(url)

# %%
s=response.text

# %%
soup=BeautifulSoup(s,"lxml")

# %%
for Alink in soup.find_all('a'):
    #print(Alink)
    print(Alink.get('href'))
# Out:
# None
# #mw-head
# #p-search
# /wiki/File:Hyphae.JPG
# /wiki/File:Hyphae.JPG
# /wiki/Mycelial_cord
# /wiki/Mycelium
# /wiki/Help:IPA/English
# #cite_note-1
# /wiki/Chemotroph#Chemoheterotroph
# /wiki/Extracellular_digestion
# /wiki/Organic_matter
# /wiki/Fungus
# /wiki/Mucor
# /wiki/Bacteria
# /wiki/Microbiome#Bacterial_flora
# https://en.wiktionary.org/wiki/sapro-
# https://en.wiktionary.org/wiki/-phyte
# /wiki/Myco-heterotrophy
# /wiki/Parasitic_plant
# /wiki/Active_transport
# /wiki/Endocytosis
# /wiki/Hypha
# #cite_note-advanced_biology_principles_1-2
# https://en.wiktionary.org/wiki/sapro
# https://en.wiktionary.org/wiki/-phyte
# /wiki/Detritivore
# /wiki/Word_sense
# /wiki/Usage
# /wiki/Lysis
# /wiki/Wikipedia:Citation_needed
# #Process
# #Conditions
# #See_also
# #References
# #Further_reading
# /w/index.php?title=Saprotrophic_nutrition&action=edit&section=1
# /wiki/Protein
# /wiki/Amino_acid
# /wiki/Protease
# #cite_note-advanced_biology_fig14.16-3
# /wiki/Lipid
# /wiki/Fatty_acid
# /wiki/Glycerol
# /wiki/Lipase
# #cite_note-advanced_biology_fig14.16-3
# /wiki/Starch
# /wiki/Amylase
# #cite_note-advanced_biology_fig14.16-3
# /wiki/Endocytosis
# #cite_note-advanced_biology_principles_1-2
# /w/index.php?title=Saprotrophic_nutrition&action=edit&section=2
# #cite_note-advanced_biology_fig14.17-4
# #cite_note-advanced_biology_fig14.17-4
# #cite_note-advanced_biology_fig14.17-4
# /wiki/PH
# #cite_note-advanced_biology_fig14.17-4
# #cite_note-advanced_biology_fig14.17-4
# /wiki/Ion
# /wiki/Maltose
# /wiki/Starch
# /wiki/Glucose
# #cite_note-advanced_biology_principles_1-2
# #cite_note-advanced_biology_principles_1-2
# /w/index.php?title=Saprotrophic_nutrition&action=edit&section=3
# /wiki/Portal:Fungi
# /wiki/Decomposers
# /wiki/Detritivore
# /wiki/Chemoautotroph
# /wiki/Photoautotroph
# /wiki/Holozoic_nutrition
# /wiki/Parasitic_nutrition
# /wiki/Mycorrhizal_fungi_and_soil_carbon_storage
# /wiki/Wood-decay_fungus
# /w/index.php?title=Saprotrophic_nutrition&action=edit&section=4
# #cite_ref-1
# https://www.oxforddictionaries.com/definition/english/saprotroph
# /wiki/OxfordDictionaries.com
# #cite_ref-advanced_biology_principles_1_2-0
# #cite_ref-advanced_biology_principles_1_2-1
# #cite_ref-advanced_biology_principles_1_2-2
# #cite_ref-advanced_biology_principles_1_2-3
# #CITEREFCleggMackean2006
# #cite_ref-advanced_biology_fig14.16_3-0
# #cite_ref-advanced_biology_fig14.16_3-1
# #cite_ref-advanced_biology_fig14.16_3-2
# #CITEREFCleggMackean2006
# #cite_ref-advanced_biology_fig14.17_4-0
# #cite_ref-advanced_biology_fig14.17_4-1
# #cite_ref-advanced_biology_fig14.17_4-2
# #cite_ref-advanced_biology_fig14.17_4-3
# #cite_ref-advanced_biology_fig14.17_4-4
# #CITEREFCleggMackean2006
# /w/index.php?title=Saprotrophic_nutrition&action=edit&section=5
# http://media.wix.com/ugd/b65817_2690a71af41f4486863a9b220827d7b5.pdf
# /wiki/Template:Modelling_ecosystems
# /wiki/Template_talk:Modelling_ecosystems
# //en.wikipedia.org/w/index.php?title=Template:Modelling_ecosystems&action=edit
# /wiki/Ecology
# /wiki/Ecosystem_model
# /wiki/Trophic_level
# /wiki/Abiotic_component
# /wiki/Abiotic_stress
# /wiki/Behavioral_ecology
# /wiki/Biogeochemical_cycle
# /wiki/Biomass_(ecology)
# /wiki/Biotic_component
# /wiki/Biotic_stress
# /wiki/Carrying_capacity
# /wiki/Competition_(biology)
# /wiki/Ecosystem
# /wiki/Ecosystem_ecology
# /wiki/Ecosystem_model
# /wiki/Keystone_species
# /wiki/List_of_feeding_behaviours
# /wiki/Metabolic_theory_of_ecology
# /wiki/Productivity_(ecology)
# /wiki/Resource_(biology)
# /wiki/Primary_producers
# /wiki/Autotroph
# /wiki/Chemosynthesis
# /wiki/Chemotroph
# /wiki/Foundation_species
# /wiki/Mixotroph
# /wiki/Myco-heterotrophy
# /wiki/Mycotroph
# /wiki/Organotroph
# /wiki/Photoheterotroph
# /wiki/Photosynthesis
# /wiki/Photosynthetic_efficiency
# /wiki/Phototroph
# /wiki/Primary_nutritional_groups
# /wiki/Primary_production
# /wiki/Consumers_(food_chain)
# /wiki/Apex_predator
# /wiki/Bacterivore
# /wiki/Carnivore
# /wiki/Chemoorganotroph
# /wiki/Foraging
# /wiki/Generalist_and_specialist_species
# /wiki/Intraguild_predation
# /wiki/Herbivore
# /wiki/Heterotroph
# /wiki/Heterotrophic_nutrition
# /wiki/Insectivore
# /wiki/Mesopredator
# /wiki/Mesopredator_release_hypothesis
# /wiki/Omnivore
# /wiki/Optimal_foraging_theory
# /wiki/Planktivore
# /wiki/Predation
# /wiki/Prey_switching
# /wiki/Decomposer
# /wiki/Chemoorganoheterotrophy
# /wiki/Decomposition
# /wiki/Detritivore
# /wiki/Detritus
# /wiki/Microorganism#Habitats_and_ecology
# /wiki/Archaea
# /wiki/Bacteriophage
# /wiki/Environmental_microbiology
# /wiki/Lithoautotroph
# /wiki/Lithotroph
# /wiki/Microbial_cooperation
# /wiki/Microbial_ecology
# /wiki/Microbial_food_web
# /wiki/Microbial_intelligence
# /wiki/Microbial_loop
# /wiki/Microbial_mat
# /wiki/Microbial_metabolism
# /wiki/Phage_ecology
# /wiki/Food_web
# /wiki/Biomagnification
# /wiki/Ecological_efficiency
# /wiki/Ecological_pyramid
# /wiki/Energy_flow_(ecology)
# /wiki/Food_chain
# /wiki/Trophic_level
# /wiki/Cold_seep
# /wiki/Hydrothermal_vent#Biological_communities
# /wiki/Intertidal_ecology
# /wiki/Kelp_forest#Trophic_ecology
# /wiki/Lake_ecosystem#Trophic_relationships
# /wiki/North_Pacific_Subtropical_Gyre
# /wiki/River_ecosystem#Trophic_relationships
# /wiki/Ecology_of_the_San_Francisco_Estuary#Food_web
# /wiki/Soil_food_web
# /wiki/Tide_pool
# /wiki/Ascendency
# /wiki/Bioaccumulation
# /wiki/Cascade_effect_(ecology)
# /wiki/Climax_community
# /wiki/Competitive_exclusion_principle
# /wiki/Consumer-resource_systems
# /wiki/Copiotroph
# /wiki/Dominance_(ecology)
# /wiki/Ecological_network
# /wiki/Ecological_succession
# /wiki/Energy_quality
# /wiki/Energy_Systems_Language
# /wiki/F-ratio
# /wiki/Feed_conversion_ratio
# /wiki/Feeding_frenzy
# /wiki/Mesotrophic_soil
# /wiki/Nutrient_cycle
# /wiki/Oligotroph
# /wiki/Paradox_of_the_plankton
# /wiki/Trophic_cascade
# /wiki/Trophic_mutualism
# /wiki/Trophic_state_index
# /wiki/Animal_coloration
# /wiki/Antipredator_adaptation
# /wiki/Camouflage
# /wiki/Deimatic_behaviour
# /wiki/Herbivore_adaptations_to_plant_defense
# /wiki/Mimicry
# /wiki/Plant_defense_against_herbivory
# /wiki/Shoaling_and_schooling#Predator_avoidance
# /wiki/Template:Modelling_ecosystems
# /wiki/Template_talk:Modelling_ecosystems
# //en.wikipedia.org/w/index.php?title=Template:Modelling_ecosystems&action=edit
# /wiki/Ecology
# /wiki/Ecosystem_model
# /wiki/Population_ecology
# /wiki/Abundance_(ecology)
# /wiki/Allee_effect
# /wiki/Depensation
# /wiki/Ecological_yield
# /wiki/Effective_population_size
# /wiki/Intraspecific_competition
# /wiki/Logistic_function
# /wiki/Malthusian_growth_model
# /wiki/Maximum_sustainable_yield
# /wiki/Overpopulation_in_wild_animals
# /wiki/Overexploitation
# /wiki/Population_cycle
# /wiki/Population_dynamics
# /wiki/Population_modeling
# /wiki/Population_size
# /wiki/Lotka%E2%80%93Volterra_equations
# /wiki/Recruitment_(biology)
# /wiki/Resilience_(ecology)
# /wiki/Small_population_size
# /wiki/Ecological_stability
# /wiki/Biodiversity
# /wiki/Density_dependence
# /wiki/Ecological_effects_of_biodiversity
# /wiki/Ecological_extinction
# /wiki/Endemic_species
# /wiki/Flagship_species
# /wiki/Gradient_analysis
# /wiki/Indicator_species
# /wiki/Introduced_species
# /wiki/Invasive_species
# /wiki/Latitudinal_gradients_in_species_diversity
# /wiki/Minimum_viable_population
# /wiki/Unified_neutral_theory_of_biodiversity
# /wiki/Occupancy%E2%80%93abundance_relationship
# /wiki/Population_viability_analysis
# /wiki/Priority_effect
# /wiki/Rapoport%27s_rule
# /wiki/Relative_abundance_distribution
# /wiki/Relative_species_abundance
# /wiki/Species_diversity
# /wiki/Species_homogeneity
# /wiki/Species_richness
# /wiki/Species_distribution
# /wiki/Species-area_curve
# /wiki/Umbrella_species
# /wiki/Antibiosis
# /wiki/Biological_interaction
# /wiki/Commensalism
# /wiki/Community_ecology
# /wiki/Ecological_facilitation
# /wiki/Interspecific_competition
# /wiki/Mutualism_(biology)
# /wiki/Parasitism
# /wiki/Storage_effect
# /wiki/Symbiosis
# /wiki/Spatial_ecology
# /wiki/Biogeography
# /wiki/Cross-boundary_subsidy
# /wiki/Ecocline
# /wiki/Ecotone
# /wiki/Ecotype
# /wiki/Disturbance_(ecology)
# /wiki/Edge_effects
# /wiki/Foster%27s_rule
# /wiki/Habitat_fragmentation
# /wiki/Ideal_free_distribution
# /wiki/Intermediate_Disturbance_Hypothesis
# /wiki/Island_biogeography
# /wiki/Landscape_ecology
# /wiki/Landscape_epidemiology
# /wiki/Landscape_limnology
# /wiki/Metapopulation
# /wiki/Patch_dynamics
# /wiki/R/K_selection_theory
# /wiki/Resource_selection_function
# /wiki/Source%E2%80%93sink_dynamics
# /wiki/Ecological_niche
# /wiki/Ecological_niche
# /wiki/Ecological_trap
# /wiki/Ecosystem_engineer
# /wiki/Environmental_niche_modelling
# /wiki/Guild_(ecology)
# /wiki/Habitat
# /wiki/Marine_habitats
# /wiki/Limiting_similarity
# /wiki/Niche_apportionment_models
# /wiki/Niche_construction
# /wiki/Niche_differentiation
# /wiki/Non-trophic_networks
# /wiki/Assembly_rules
# /wiki/Bateman%27s_principle
# /wiki/Bioluminescence
# /wiki/Ecological_collapse
# /wiki/Ecological_debt
# /wiki/Ecological_deficit
# /wiki/Ecological_energetics
# /wiki/Ecological_indicator
# /wiki/Ecological_threshold
# /wiki/Ecosystem_diversity
# /wiki/Emergence
# /wiki/Extinction_debt
# /wiki/Kleiber%27s_law
# /wiki/Liebig%27s_law_of_the_minimum
# /wiki/Marginal_value_theorem
# /wiki/Thorson%27s_rule
# /wiki/Xerosere
# /wiki/Allometry
# /wiki/Alternative_stable_state
# /wiki/Balance_of_nature
# /wiki/Biological_data_visualization
# /wiki/Cline_(biology)
# /wiki/Ecological_economics
# /wiki/Ecological_footprint
# /wiki/Ecological_forecasting
# /wiki/Ecological_humanities
# /wiki/Ecological_stoichiometry
# /wiki/Ecopath
# /wiki/Ecosystem_based_fisheries
# /wiki/Endolith
# /wiki/Evolutionary_ecology
# /wiki/Functional_ecology
# /wiki/Industrial_ecology
# /wiki/Macroecology
# /wiki/Microecosystem
# /wiki/Natural_environment
# /wiki/Regime_shift
# /wiki/Systems_ecology
# /wiki/Urban_ecology
# /wiki/Theoretical_ecology
# /wiki/List_of_ecology_topics
# https://en.wikipedia.org/w/index.php?title=Saprotrophic_nutrition&oldid=900115123
# /wiki/Help:Category
# /wiki/Category:Nutrition
# /wiki/Category:Mycology
# /wiki/Category:Dead_wood
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_March_2016
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Saprotrophic+nutrition
# /w/index.php?title=Special:UserLogin&returnto=Saprotrophic+nutrition
# /wiki/Saprotrophic_nutrition
# /wiki/Talk:Saprotrophic_nutrition
# /wiki/Saprotrophic_nutrition
# /w/index.php?title=Saprotrophic_nutrition&action=edit
# /w/index.php?title=Saprotrophic_nutrition&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Portal:Contents
# /wiki/Portal:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# //shop.wikimedia.org
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Special:WhatLinksHere/Saprotrophic_nutrition
# /wiki/Special:RecentChangesLinked/Saprotrophic_nutrition
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Saprotrophic_nutrition&oldid=900115123
# /w/index.php?title=Saprotrophic_nutrition&action=info
# https://www.wikidata.org/wiki/Special:EntityPage/Q23001591
# /w/index.php?title=Special:CiteThisPage&page=Saprotrophic_nutrition&id=900115123
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=Saprotrophic+nutrition
# /w/index.php?title=Special:ElectronPdf&page=Saprotrophic+nutrition&action=show-download-screen
# /w/index.php?title=Saprotrophic_nutrition&printable=yes
# https://ar.wikipedia.org/wiki/%D8%AA%D8%BA%D8%B0%D9%8A%D8%A9_%D8%AA%D8%B1%D9%85%D9%85%D9%8A%D8%A9
# https://ca.wikipedia.org/wiki/Saprotrofia
# https://gl.wikipedia.org/wiki/Saprotrofia
# https://id.wikipedia.org/wiki/Saprofit
# https://sr.wikipedia.org/wiki/%D0%A1%D0%B0%D0%BF%D1%80%D0%BE%D1%82%D1%80%D0%BE%D1%84%D0%B8
# https://sv.wikipedia.org/wiki/Saprotrofi
# https://zh.wikipedia.org/wiki/%E8%85%90%E7%94%9F
# https://www.wikidata.org/wiki/Special:EntityPage/Q23001591#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://foundation.wikimedia.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Saprotrophic_nutrition&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
for ptag in soup.find_all("p"):
    #print(ptag)
    for btag in ptag.find_all("b"):
        print(btag.text)
# Out:
# Saprotrophic nutrition
# lysotrophic nutrition
# saprotrophs
# saprobes
# saprophytes
# facultative saprophyte
